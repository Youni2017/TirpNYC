# %%
import pandas as pd

yellow_df = pd.read_parquet("yellow_tripdata_2025-08.parquet")

print(yellow_df.shape)     
print(yellow_df.columns)    
print(yellow_df.head())
# Out:
# (3574091, 20)
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'Airport_fee',
#        'cbd_congestion_fee'],
#       dtype='object')
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2025-08-01 00:52:23   2025-08-01 01:12:20              1.0
# 1         2  2025-08-01 00:03:01   2025-08-01 00:15:33              2.0
# 2         7  2025-08-01 00:24:38   2025-08-01 00:24:38              2.0
# 3         7  2025-08-01 00:48:19   2025-08-01 00:48:19              1.0
# 4         2  2025-08-01 00:25:34   2025-08-01 00:33:18              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# ...

# %%
yellow_df.head(5)
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2025-08-01 00:52:23   2025-08-01 01:12:20              1.0
# 1         2  2025-08-01 00:03:01   2025-08-01 00:15:33              2.0
# 2         7  2025-08-01 00:24:38   2025-08-01 00:24:38              2.0
# 3         7  2025-08-01 00:48:19   2025-08-01 00:48:19              1.0
# 4         2  2025-08-01 00:25:34   2025-08-01 00:33:18              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           8.44         1.0                  N           138           141
# 1           4.98         1.0                  N           138           193
# 2           1.89         1.0                  N           249            45
# 3           2.35         1.0                  N            79           229
# 4           2.14         1.0                  N            43            48
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
green_df = pd.read_parquet("green_tripdata_2025-08.parquet")

print(green_df.shape)       
print(green_df.columns) 
print(green_df.head())
# Out:
# (46306, 21)
# Index(['VendorID', 'lpep_pickup_datetime', 'lpep_dropoff_datetime',
#        'store_and_fwd_flag', 'RatecodeID', 'PULocationID', 'DOLocationID',
#        'passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'ehail_fee', 'improvement_surcharge',
#        'total_amount', 'payment_type', 'trip_type', 'congestion_surcharge',
#        'cbd_congestion_fee'],
#       dtype='object')
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2025-08-01 00:33:57   2025-08-01 00:58:10                  N
# 1         2  2025-08-01 00:01:00   2025-08-01 00:12:58                  N
# 2         2  2025-08-01 00:11:02   2025-08-01 00:16:06                  N
# 3         2  2025-08-01 00:44:09   2025-08-01 00:47:04                  N
# 4         2  2025-08-01 00:57:06   2025-08-01 01:05:32                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# ...

# %%
green_df.head(5)
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2025-08-01 00:33:57   2025-08-01 00:58:10                  N
# 1         2  2025-08-01 00:01:00   2025-08-01 00:12:58                  N
# 2         2  2025-08-01 00:11:02   2025-08-01 00:16:06                  N
# 3         2  2025-08-01 00:44:09   2025-08-01 00:47:04                  N
# 4         2  2025-08-01 00:57:06   2025-08-01 01:05:32                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            70            82              1.0           2.44
# 1         1.0           130           216              1.0           4.06
# 2         1.0            74           263              1.0           2.09
# 3         1.0            42            41              1.0           0.53
# 4         1.0            75           239              1.0           2.28
#
#    fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
fhvhv_df = pd.read_parquet("fhvhv_tripdata_2025-08.parquet")

print(fhvhv_df.shape)      
print(fhvhv_df.columns)  
print(fhvhv_df.head())
# Out:
# (19271461, 25)
# Index(['hvfhs_license_num', 'dispatching_base_num', 'originating_base_num',
#        'request_datetime', 'on_scene_datetime', 'pickup_datetime',
#        'dropoff_datetime', 'PULocationID', 'DOLocationID', 'trip_miles',
#        'trip_time', 'base_passenger_fare', 'tolls', 'bcf', 'sales_tax',
#        'congestion_surcharge', 'airport_fee', 'tips', 'driver_pay',
#        'shared_request_flag', 'shared_match_flag', 'access_a_ride_flag',
#        'wav_request_flag', 'wav_match_flag', 'cbd_congestion_fee'],
#       dtype='object')
#   hvfhs_license_num dispatching_base_num originating_base_num  \
# 0            HV0003               B03404               B03404
# 1            HV0003               B03404               B03404
# 2            HV0003               B03404               B03404
# 3            HV0003               B03404               B03404
# 4            HV0003               B03404               B03404
#
# ...

# %%
fhvhv_df.head(5)
# Out:
#   hvfhs_license_num dispatching_base_num originating_base_num  \
# 0            HV0003               B03404               B03404
# 1            HV0003               B03404               B03404
# 2            HV0003               B03404               B03404
# 3            HV0003               B03404               B03404
# 4            HV0003               B03404               B03404
#
#      request_datetime   on_scene_datetime     pickup_datetime  \
# 0 2025-08-01 00:07:01 2025-08-01 00:09:06 2025-08-01 00:09:29
# 1 2025-08-01 00:31:28 2025-08-01 00:35:30 2025-08-01 00:35:50
# 2 2025-08-01 00:53:16 2025-08-01 00:54:54 2025-08-01 00:56:55
# 3 2025-08-01 00:52:57 2025-08-01 00:54:47 2025-08-01 00:56:10
# 4 2025-08-01 00:06:10 2025-08-01 00:09:20 2025-08-01 00:09:44
#
#      dropoff_datetime  PULocationID  DOLocationID  trip_miles  ...  \
# 0 2025-08-01 00:22:28           113           158        1.53  ...
# 1 2025-08-01 00:46:56           144            68        2.06  ...
# ...

# %%
import pandas as pd
df = pd.read_parquet("yellow_tripdata_2025-08.parquet")
df.to_csv("yellow_tripdata_2025-08.csv", index=False)

# %%
import pandas as pd
df = pd.read_parquet("green_tripdata_2025-08.parquet")
df.to_csv("green_tripdata_2025-08.csv", index=False)

# %%
import pandas as pd
df = pd.read_parquet("fhvhv_tripdata_2025-08.parquet")
df.to_csv("fhvhv_tripdata_2025-08.csv", index=False)

# %%
import pandas as pd
df = pd.read_parquet("yellow_tripdata_2025-08.parquet")
df.to_csv("yellow_tripdata_2025-08.csv", index=False)

# %%
pd.read_csv("yellow_tripdata_2025-08.csv")
# Out:
# /var/folders/rq/d1f380z1435dgk98n9b9hwz40000gn/T/ipykernel_6624/1313048019.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv("yellow_tripdata_2025-08.csv")
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2025-08-01 00:52:23   2025-08-01 01:12:20              1.0
# 1               2  2025-08-01 00:03:01   2025-08-01 00:15:33              2.0
# 2               7  2025-08-01 00:24:38   2025-08-01 00:24:38              2.0
# 3               7  2025-08-01 00:48:19   2025-08-01 00:48:19              1.0
# 4               2  2025-08-01 00:25:34   2025-08-01 00:33:18              1.0
# ...           ...                  ...                   ...              ...
# 3574086         2  2025-08-31 23:40:30   2025-08-31 23:58:48              NaN
# 3574087         2  2025-08-31 23:10:26   2025-08-31 23:29:01              NaN
# ...
